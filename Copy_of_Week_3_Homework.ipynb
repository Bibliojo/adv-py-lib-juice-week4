# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibliojo/adv-py-lib-juice-week4/blob/main/Copy_of_Week_3_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Homework
#
# (Be sure to copy to drive first)
#
# For this homework we are going to apply some text analysis stuff to a collection of PDF file that I'll ask you to put together.

# %%
#Install / load our libraries and connect to Google Drive

# !pip install pypdf

#Colab has a special library just for working with files on google drive
from google.colab import drive


#This is a new library we'll use to extract text from PDFs
from pypdf import PdfReader


import textblob
import pandas as pd
import numpy as np
import glob

#Some extra libraries we'll need for text analysis
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('punkt_tab')

#Connect to Gdrive
drive.mount('/content/gdrive')

print("Libraries and Drive Ready!")
# Out:
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (6.0.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Libraries and Drive Ready!

# %% [markdown]
# **H1**
#
#
# Part of the work for this week is going to be finding a collection of 6 or so PDFs. These PDFS ideally should be on the same thing (journal articles on the same topic). Additionally these PDFs whould be Open Access, or the very least obtained lawfully * ***ahem*** *.
#
# Copy these 6 PDFs into the `LibraryJuicePython` folder on Google Drive. We'll be peforming some text analysis on these files.

# %%
#Run this cell to see the files in your directory
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  print(file)
# Out:
# /content/gdrive/MyDrive/LibraryJuicePython/2106.15320v1.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/2107.00516v1 (1).pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Digital Preservation Accessibility and Use of Electronic Theses.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/MetaEnhance-arXiv.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf

# %% [markdown]
# # Exracting the text from the PDFs
#
# We'll use a Python Library to create a text file of the contents of the PDF file.

# %%
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  filename = file.split("/")[-1]
  print("Extracting text for... ",filename)

  text = ""
  #This bit is new!
  reader = PdfReader(file)
  for page in reader.pages:
    text += page.extract_text()

  #Output the string variable into a text file
  output_text_file = filename+".txt"
  with open(output_text_file, "w") as text_file:
    text_file.write(text)
# Out:
# Extracting text for...  2106.15320v1.pdf
# Extracting text for...  2107.00516v1 (1).pdf
# Extracting text for...  Digital Preservation Accessibility and Use of Electronic Theses.pdf
# Extracting text for...  MetaEnhance-arXiv.pdf
# Extracting text for...  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf
# Extracting text for...  Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf

# %% [markdown]
# # Sentiment of our PDFs
#
# Let's just print our sentiment scores to the screen for now.

# %%
for file in glob.glob("*.txt"):
  print("Sentiment for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()
    blob = textblob.TextBlob(text)
    print(blob.sentiment)
    print("---")
# Out:
# Sentiment for  MetaEnhance-arXiv.pdf.txt
# Sentiment(polarity=0.051319576719576716, subjectivity=0.38565422725422704)
# ---
# Sentiment for  2107.00516v1 (1).pdf.txt
# Sentiment(polarity=0.03882787719193248, subjectivity=0.357473402173863)
# ---
# Sentiment for  2106.15320v1.pdf.txt
# Sentiment(polarity=0.07005936639118457, subjectivity=0.4004113870977514)
# ---
# Sentiment for  Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt
# Sentiment(polarity=0.023144752588166322, subjectivity=0.36946445638467945)
# ---
# Sentiment for  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt
# Sentiment(polarity=0.0884949013949013, subjectivity=0.3569738335738334)
# ---
# Sentiment for  Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt
# Sentiment(polarity=0.07232002725030616, subjectivity=0.3295585059031274)
# ---

# %% [markdown]
# # Noun Phrases of our PDFs
#
# We'll just do the top 3 keywords of each file and display it to the screen

# %%
for file in glob.glob("*.txt"):
  print("Top 3 Phrases for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()

  blob = textblob.TextBlob(text)
  nphrases = dict()

  for np in blob.noun_phrases:
    if np in nphrases:
         nphrases[np] += 1
    else:
         nphrases[np] = 1

  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:3]:
      print(np, nphrases[np])

  print("---")
# Out:
# Top 3 Phrases for  MetaEnhance-arXiv.pdf.txt
# etds 31
# metadata quality 14
# autometa 13
# ---
# Top 3 Phrases for  2107.00516v1 (1).pdf.txt
# etds 30
# crf 19
# ocr 9
# ---
# Top 3 Phrases for  2106.15320v1.pdf.txt
# deep figures 59
# yolov5 54
# etds 46
# ---
# Top 3 Phrases for  Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt
# ph.d. 54
# digital library 35
# novi sad 34
# ---
# Top 3 Phrases for  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt
# electronic thesis 10
# libraries 9
# subject 9
# ---
# Top 3 Phrases for  Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt
# nigeria 56
# etds 21
# university libraries 21
# ---

# %% [markdown]
# # Dataframe of results
#
# Let's put our findings into a dataframe and save them to our drive. (We will use these PDFs again in our Week 4 work)

# %%
data_set = []

for file in glob.glob("*.txt"):

  pdf_detail = []

  with open(file,"r") as text_file:
    text = text_file.read()
  blob = textblob.TextBlob(text)

  print("working on ",file)
  pdf_detail.append(file)
  pdf_detail.append(blob.sentiment.polarity)
  pdf_detail.append(blob.sentiment.subjectivity)


  nphrases = dict()
  for np in blob.noun_phrases:
    if np in nphrases:
      nphrases[np] += 1
    else:
      nphrases[np] = 1

  #This is a weird way to find the top three keywords
  #This is an example of 'hacky' code

  #we loop through the first entry [0:1] in the sorted keyword list
  #giving us keyword one
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:1]:
      keyword_one = np
      pdf_detail.append(keyword_one)

  #we loop through the first entry [1:2] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[1:2]:
      keyword_two = np
      pdf_detail.append(keyword_two)

  #we loop through the first entry [2:3] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[2:3]:
      keyword_three = np
      pdf_detail.append(keyword_three)

  data_set.append(pdf_detail)
  print(pdf_detail)
  print("---")
# Out:
# working on  MetaEnhance-arXiv.pdf.txt
# ['MetaEnhance-arXiv.pdf.txt', 0.051319576719576716, 0.38565422725422704, 'etds', 'metadata quality', 'autometa']
# ---
# working on  2107.00516v1 (1).pdf.txt
# ['2107.00516v1 (1).pdf.txt', 0.03882787719193248, 0.357473402173863, 'etds', 'crf', 'ocr']
# ---
# working on  2106.15320v1.pdf.txt
# ['2106.15320v1.pdf.txt', 0.07005936639118457, 0.4004113870977514, 'deep figures', 'yolov5', 'etds']
# ---
# working on  Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt
# ['Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt', 0.023144752588166322, 0.36946445638467945, 'ph.d.', 'digital library', 'novi sad']
# ---
# working on  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt
# ['Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt', 0.0884949013949013, 0.3569738335738334, 'electronic thesis', 'libraries', 'subject']
# ---
# working on  Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt
# ['Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt', 0.07232002725030616, 0.3295585059031274, 'nigeria', 'etds', 'university libraries']
# ---

# %%
#We now have a list of lists
#This sorta looks like JSON doesn't it?
data_set
# Out:
# [['MetaEnhance-arXiv.pdf.txt',
#   0.051319576719576716,
#   0.38565422725422704,
#   'etds',
#   'metadata quality',
#   'autometa'],
#  ['2107.00516v1 (1).pdf.txt',
#   0.03882787719193248,
#   0.357473402173863,
#   'etds',
#   'crf',
#   'ocr'],
#  ['2106.15320v1.pdf.txt',
#   0.07005936639118457,
#   0.4004113870977514,
#   'deep figures',
#   'yolov5',
#   'etds'],
#  ['Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt',
#   0.023144752588166322,
#   0.36946445638467945,
#   'ph.d.',
#   'digital library',
#   'novi sad'],
#  ['Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt',
#   0.0884949013949013,
#   0.3569738335738334,
#   'electronic thesis',
#   'libraries',
#   'subject'],
#  ['Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt',
#   0.07232002725030616,
#   0.3295585059031274,
#   'nigeria',
#   'etds',
#   'university libraries']]

# %%
#Let's turn this list of lists into a pandas dataframe
pdf_dataframe = pd.DataFrame(data_set)
pdf_dataframe
# Out:
#                                                    0         1         2  \
# 0                          MetaEnhance-arXiv.pdf.txt  0.051320  0.385654
# 1                           2107.00516v1 (1).pdf.txt  0.038828  0.357473
# 2                               2106.15320v1.pdf.txt  0.070059  0.400411
# 3  Six Steps Toward Improving Discoverability of ...  0.023145  0.369464
# 4  Design and Development of Subject Gateway of E...  0.088495  0.356974
# 5  Digital Preservation Accessibility and Use of ...  0.072320  0.329559
#
#                    3                 4                     5
# 0               etds  metadata quality              autometa
# 1               etds               crf                   ocr
# 2       deep figures            yolov5                  etds
# 3              ph.d.   digital library              novi sad
# 4  electronic thesis         libraries               subject
# 5            nigeria              etds  university libraries

# %% [markdown]
# **H2**
#
# Our dataframe needs better column names. Put the appropriate values into the list below on line 1 to update the column names.

# %%
column_names = ["pdf_name","polarity","subjectivity","noun_phrase1","noun_phrase2","noun_phrase3"]
pdf_dataframe.columns = column_names
pdf_dataframe
# Out:
#                                             pdf_name  polarity  subjectivity  \
# 0                          MetaEnhance-arXiv.pdf.txt  0.051320      0.385654
# 1                           2107.00516v1 (1).pdf.txt  0.038828      0.357473
# 2                               2106.15320v1.pdf.txt  0.070059      0.400411
# 3  Six Steps Toward Improving Discoverability of ...  0.023145      0.369464
# 4  Design and Development of Subject Gateway of E...  0.088495      0.356974
# 5  Digital Preservation Accessibility and Use of ...  0.072320      0.329559
#
#         noun_phrase1      noun_phrase2          noun_phrase3
# 0               etds  metadata quality              autometa
# 1               etds               crf                   ocr
# 2       deep figures            yolov5                  etds
# 3              ph.d.   digital library              novi sad
# 4  electronic thesis         libraries               subject
# 5            nigeria              etds  university libraries

# %% [markdown]
# # Save our data
#
# We'll save our dataframe as a CSV file and put it in our usual folder.

# %%
pdf_dataframe.to_csv("adv_week3_homework.csv", index=False)
# !cp adv_week3_homework.csv /content/gdrive/MyDrive/LibraryJuicePython

# %% [markdown]
# **H3** Take a moment to reflect on what your data analysis says about your PDF files. Jot down some reflections in the cell below.

# %% [markdown]
# My analysis tells me... the sentiment is rather neutral, objective. No drama here! but that's to be expected of thess kinds of paper.  The nost used nouns my not be very helpful as search terms on their own. Nigeria. phd. yolov5? (I don't even know what that means LOL)

# %% [markdown]
# # All Done!
#
# Congrats you are finished with this week's work. Don't forget to click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work. Save this as a PDF and upload it to the Library Juice Academy site.
