# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibliojo/adv-py-lib-juice-week4/blob/main/Copy_of_Week_4_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Homework
#
# (Be sure to copy to drive)
#
# I have put a lot different things in front of you during this course. Thanks for indulging me as I try to both impress you with what Python can do, and make the code readable.
#
# For homework this week, we are going to go real light.

# %% [markdown]
# **H1** To bring what you learned in the week 4 warmup to life I'd like you to:
#
# - Create a GitHub repository
# - Save your week 1 homework in that GitHub Repository in the way described in the warmup
# - Share the URL to your repository in the cell below

# %%
repository_url = "https://github.com/Bibliojo/adv-py-lib-juice-week4/blob/main/Copy_of_Week_1_Homework.ipynb"

# %% [markdown]
# **H1 Continued**
#
# You don't have to keep that repository forever, feel free to delete it after this class is done.

# %% [markdown]
# **H2** Starting in the week 3 homework we began an analysis on a collection of PDF files that you created. The week 4 workalong asked you to create PDF summaries for those same files.
#
# I'd just like to see what your final analysis looks like. Run the cells below to load up those csv files and to display them to the screen.

# %%
from google.colab import drive
import pandas as pd

#Because the summaries are big, I'm going to set no maximum column size in pandas so I see
#the complete summary
pd.set_option('display.max_colwidth', None)

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # PDF Summaries

# %%
pdf_summaries = pd.read_csv("/content/gdrive/MyDrive/LibraryJuicePython/adv_week4_pdf_summaries.csv")
pdf_summaries
# Out:
#                                                                                                                              Filename  \
# 0                                                                                                               MetaEnhance-arXiv.pdf
# 1                                                                                                                2107.00516v1 (1).pdf
# 2                                                                                                                    2106.15320v1.pdf
# 3                                                                 Digital Preservation Accessibility and Use of Electronic Theses.pdf
# 4  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf
# 5                                                               Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf
#
#                                                                                                                                                                                                                                                                                                                                                                                                         Summary
# 0                                    Metadata quality is crucial for digital objects to be discovered through digital library interfaces. Metadata of digital objects often exhibits incomplete, in-consistent, and incorrect values. We investigate methods to automatically detect, correct, and canonicalize scholarly metadata, using seven key electronic theses and dissertations (ETDs) as a case study.
# 1               Electronic Theses and Dissertations (ETDs) contain domain knowledge that can be used for many digital library tasks. Traditional sequence tagging methods mainly rely on text-basedfeatures. In this paper, we propose a conditional random ﬁeld (CRF) model that combines text and visual features. The data and source code are publicly available on Google Drive1 and a GitHub repository2.
# 2  Research focuses on Electronic Theses and Dissertations (ETDs), aiming to improve access and expand their utility. Since more than 6 million ETDs are publicly available, they constitute an important corpus to aid research and education across disciplines. We present ScanBank, a new dataset to train a deep neural network based on YOLOv5 to accurately extract ﬁgures and tables from scanned ETDs.
# 3                                                This study examined the concepts and aspects of digitization in university libraries in six geopolitical zones of Nigeria. Print theses and dissertations (T/Ds) are digitized by document scanning or alphanumeric characters into computer systems. Digital resources include e-books, e-journals, ETDs, and other forms of documents in electronic formats.
# 4                                                                                                                                                                                                            Summarize: INNOVATIVE LIBRARIANSHIP. Impetus to Digital Convergence. Dr. S. Dhanavandan. TTPP: 4436/7, Ansari Road, Daryaganj, New Delhi - 110 002 (India) Ph : 23242621; 23241021; Fax 2324 2621.
# 5                                                                                                                        Six Steps Toward Improving Discoverability of Ph.D. Dissertations Six steps used by the University of Novi Sad, Serbia, to develop a searchable e-theses to export to other digital library networks. 400,000 downloads have been performed since the digital library was operational.

# %% [markdown]
# #PDF Details

# %%
pdf_data = pd.read_csv("/content/gdrive/MyDrive/LibraryJuicePython/adv_week3_homework.csv")
pdf_data
# Out:
#                                                                                                                                  pdf_name  \
# 0                                                                                                               MetaEnhance-arXiv.pdf.txt
# 1                                                                                                                2107.00516v1 (1).pdf.txt
# 2                                                                                                                    2106.15320v1.pdf.txt
# 3                                                               Six Steps Toward Improving Discoverability of Ph.D. Dissertations.pdf.txt
# 4  Design and Development of Subject Gateway of Electronic Thesis and Dissertation with Special Refernce to Southern Universities.pdf.txt
# 5                                                                 Digital Preservation Accessibility and Use of Electronic Theses.pdf.txt
#
#    polarity  subjectivity       noun_phrase1      noun_phrase2  \
# 0  0.051320      0.385654               etds  metadata quality
# 1  0.038828      0.357473               etds               crf
# 2  0.070059      0.400411       deep figures            yolov5
# 3  0.023145      0.369464              ph.d.   digital library
# 4  0.088495      0.356974  electronic thesis         libraries
# 5  0.072320      0.329559            nigeria              etds
#
#            noun_phrase3
# 0              autometa
# 1                   ocr
# 2                  etds
# 3              novi sad
# 4               subject
# 5  university libraries

# %% [markdown]
# ## All Done!
#
# Congrats you have finished Advanced Python for Librarians!
#
# Don't forget to click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work. Please also save this notebook as a PDF and upload it the Library Juice Academy LMS.
